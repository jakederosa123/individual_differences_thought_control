# %%
import sys 
sys.path.append('/pl/active/banich/studies/Relevantstudies/abcd/env/lib/python3.7/site-packages')
sys.path.append('/pl/active/banich/studies/Clearvale/jake_scripts/Amy_flywheel_scripts/')

import numpy as np
import pandas as pd
import os

# %%
z_data = pd.read_csv('/pl/active/banich/studies/wmem/fmri/operation_rsa/grp/gradients/analysis/ClearMem_Z_Average.csv')
z_data = z_data[['SubID', 'z_ave', 'PSWQ_total', 'WBSI_total', 'RRS_total', 'RRS_depression', 'RRS_brooding', 'RRS_reflection']]
z_data = z_data.dropna()

from scipy.stats import zscore
z_data['br_z_ave'] = z_data['z_ave']
z_data.drop('z_ave', axis=1, inplace=True)
z_data['b_z_ave'] = (zscore(z_data['PSWQ_total']) + zscore(z_data['WBSI_total']) + zscore(z_data['RRS_brooding']))/3
z_data['thought_problems'] = (zscore(z_data['PSWQ_total']) + zscore(z_data['WBSI_total']) + zscore(z_data['RRS_brooding']) + zscore(z_data['RRS_reflection']) + zscore(z_data['RRS_depression']))/5

#all_metrics_z= z_data.drop(['PSWQ_total', 'WBSI_total','RRS_total', 'RRS_depression', 
#                     'RRS_brooding', 'RRS_reflection', 'br_z_ave'], axis=1)

# %%
op_mat_sub_ids = pd.read_csv('/pl/active/banich/studies/wmem/fmri/operation_rsa/grp/gradients/subj/matched_subid.csv')

# %%
sub_rsa_mat_cors = pd.read_csv('/pl/active/banich/studies/wmem/fmri/operation_rsa/grp/bootstrapped_regressions/sub_rsa_mat_cors.csv')   
sub_rsa_mat_cors = pd.merge(op_mat_sub_ids, sub_rsa_mat_cors, on='sub').drop('sub', axis=1)

# %%
sub_rsa_mat_cors_z = pd.merge(z_data[['SubID', 'thought_problems']], sub_rsa_mat_cors, on='SubID')

# %%
#sub_rsa_mat_cors_z

# %%
import pandas as pd
import statsmodels.api as sm
import statsmodels.formula.api as smf
import itertools

class RegressionAnalysis:
    def __init__(self, data, variable_list, target='thought_problems', interaction=None):
        self.data = data
        self.variable_list = variable_list
        self.target = target
        self.interaction = interaction
        self.regression_results = {}
        self.regression_models = {}

    def run_regression(self, target, y_vars):
        if self.interaction is not None:
            if len(y_vars) > 1:
                joined_vars = ' * '.join(y_vars)
            else:
                joined_vars = y_vars[0]
            formula = f'{target} ~ {joined_vars}'
        else:
            joined_vars = ' + '.join(y_vars)
            formula = f'{target} ~ {joined_vars}'

        model = smf.ols(formula=formula, data=self.data).fit()
        summary = model.summary()
        var = pd.DataFrame(summary.tables[0].data).iloc[0, 1]

        table1 = pd.DataFrame(summary.tables[0].data).iloc[:4, 3:].T.assign(var=var)
        table1.columns = ['r2', 'adjr2', 'fstat', 'pval', 'var']
        table1 = table1[['var', 'r2', 'adjr2', 'fstat', 'pval']]

        table2_cols = pd.DataFrame(summary.tables[1].data).loc[0].to_list() + ['var']
        table2_cols[0] = 'parameter'
        table2 = pd.DataFrame(summary.tables[1].data).iloc[1:].assign(var=var)
        table2.columns = table2_cols
        table2 = table2[['var', 'parameter', 'coef', 'std err', 't', 'P>|t|']]

        df = pd.merge(table1, table2, how='outer', left_on='var', right_on='parameter')
        df['var'] = df['var_x'].fillna(df['var_y'])
        df.drop(columns=['var_x', 'var_y'], inplace=True)
        df = df[['var'] + [col for col in df.columns if col != 'var']]
        df = df.assign(formula=formula)

        return df, model

    def run_all_regressions(self):
        for metric in self.variable_list:
            df, model = self.run_regression(self.target, [metric])
            self.regression_results[metric] = df
            self.regression_models[metric] = model

    def get_combined_results(self):
        combined_results = []
        for metric in self.regression_results:
            combined_results.append(self.regression_results[metric])

        output_regressions = pd.concat(combined_results, ignore_index=True)
        columns_to_convert = ['r2', 'adjr2', 'fstat', 'pval', 'coef', 'std err', 't', 'P>|t|']
        for column in columns_to_convert:
            output_regressions[column] = pd.to_numeric(output_regressions[column], errors='coerce')

        return output_regressions
    
def clean_formulas(dataframe, pval_threshold=0.05, target_prefix='thought_problems ~ '):
    """
    Filters formulas in a DataFrame based on p-value and removes the target prefix from each formula.

    Parameters:
    dataframe (pd.DataFrame): The DataFrame containing the regression results.
    pval_threshold (float): The p-value threshold for filtering formulas. Default is 0.05.
    target_prefix (str): The prefix to remove from each formula. Default is 'thought_problems ~ '.

    Returns:
    list: A list of cleaned formulas.
    """
    filtered_formulas = dataframe.query('pval < @pval_threshold').formula.to_list()
    cleaned_formulas = [formula.replace(target_prefix, '') for formula in filtered_formulas]
    return cleaned_formulas

# %%
def format_og_regs(regressions_table, neural_met):
    
    regressions_table = regressions_table.query('parameter != "Intercept"')
    
    outs = (regressions_table
     .melt(id_vars='formula')
     .dropna()
     .query('value != "thought_problems"')
     .reset_index()
     .pivot(index=['index', 'formula'], columns='variable', values='value')
    ).reset_index().sort_values('formula')

    # Group by formula and aggregate the non-NA values
    agg_funcs = {col: 'first' for col in outs.columns if col != 'formula'}
    collapsed_df = outs.groupby('formula').agg(agg_funcs).reset_index().assign(data_type = neural_met)

    collapsed_df = collapsed_df[['data_type', 'parameter', 'fstat', 'r2', 'adjr2', 'std err', 't', 'pval',]]
    
    return collapsed_df

# %%
cor_list = sub_rsa_mat_cors_z.iloc[:, 2:].columns.to_list()

# %%
# Usage example
cor_list = sub_rsa_mat_cors_z.iloc[:, 2:].columns.to_list()

cor_analysis = RegressionAnalysis(sub_rsa_mat_cors_z, cor_list)
cor_analysis.run_all_regressions()
cor_output_regressions = cor_analysis.get_combined_results()
cor_regression_models = cor_analysis.regression_models
cor_sig_vars = clean_formulas(cor_output_regressions)

# %%
cor_output_regressions
# Out:
#                  var     r2  adjr2     fstat   pval           parameter  \
# 0   thought_problems  0.005 -0.016  0.249700  0.620                 NaN
# 1   thought_problems    NaN    NaN       NaN    NaN           Intercept
# 2   thought_problems    NaN    NaN       NaN    NaN           main_cors
# 3   thought_problems  0.003 -0.018  0.148600  0.702                 NaN
# 4   thought_problems    NaN    NaN       NaN    NaN           Intercept
# 5   thought_problems    NaN    NaN       NaN    NaN        replace_cors
# 6   thought_problems  0.002 -0.020  0.092190  0.763                 NaN
# 7   thought_problems    NaN    NaN       NaN    NaN           Intercept
# 8   thought_problems    NaN    NaN       NaN    NaN       suppress_cors
# 9   thought_problems  0.008 -0.014  0.366200  0.548                 NaN
# 10  thought_problems    NaN    NaN       NaN    NaN           Intercept
# 11  thought_problems    NaN    NaN       NaN    NaN          clear_cors
# 12  thought_problems  0.000 -0.022  0.000129  0.991                 NaN
# 13  thought_problems    NaN    NaN       NaN    NaN           Intercept
# 14  thought_problems    NaN    NaN       NaN    NaN      clear_cors_DMN
# 15  thought_problems  0.000 -0.022  0.000124  0.991                 NaN
# 16  thought_problems    NaN    NaN       NaN    NaN           Intercept
# 17  thought_problems    NaN    NaN       NaN    NaN     clear_cors_FPCN
# 18  thought_problems  0.001 -0.020  0.062680  0.803                 NaN
# 19  thought_problems    NaN    NaN       NaN    NaN           Intercept
# 20  thought_problems    NaN    NaN       NaN    NaN      clear_cors_SMN
# 21  thought_problems  0.000 -0.022  0.003379  0.954                 NaN
# 22  thought_problems    NaN    NaN       NaN    NaN           Intercept
# 23  thought_problems    NaN    NaN       NaN    NaN       clear_cors_VN
# 24  thought_problems  0.003 -0.019  0.126800  0.723                 NaN
# 25  thought_problems    NaN    NaN       NaN    NaN           Intercept
# 26  thought_problems    NaN    NaN       NaN    NaN       main_cors_DMN
# 27  thought_problems  0.000 -0.021  0.022430  0.882                 NaN
# 28  thought_problems    NaN    NaN       NaN    NaN           Intercept
# 29  thought_problems    NaN    NaN       NaN    NaN      main_cors_FPCN
# 30  thought_problems  0.000 -0.022  0.005112  0.943                 NaN
# 31  thought_problems    NaN    NaN       NaN    NaN           Intercept
# 32  thought_problems    NaN    NaN       NaN    NaN       main_cors_SMN
# 33  thought_problems  0.000 -0.021  0.016550  0.898                 NaN
# 34  thought_problems    NaN    NaN       NaN    NaN           Intercept
# 35  thought_problems    NaN    NaN       NaN    NaN        main_cors_VN
# 36  thought_problems  0.000 -0.022  0.009530  0.923                 NaN
# 37  thought_problems    NaN    NaN       NaN    NaN           Intercept
# 38  thought_problems    NaN    NaN       NaN    NaN    replace_cors_DMN
# 39  thought_problems  0.000 -0.022  0.009151  0.924                 NaN
# 40  thought_problems    NaN    NaN       NaN    NaN           Intercept
# 41  thought_problems    NaN    NaN       NaN    NaN   replace_cors_FPCN
# 42  thought_problems  0.000 -0.021  0.014140  0.906                 NaN
# 43  thought_problems    NaN    NaN       NaN    NaN           Intercept
# 44  thought_problems    NaN    NaN       NaN    NaN    replace_cors_SMN
# 45  thought_problems  0.000 -0.022  0.008912  0.925                 NaN
# 46  thought_problems    NaN    NaN       NaN    NaN           Intercept
# 47  thought_problems    NaN    NaN       NaN    NaN     replace_cors_VN
# 48  thought_problems  0.007 -0.014  0.347100  0.559                 NaN
# 49  thought_problems    NaN    NaN       NaN    NaN           Intercept
# 50  thought_problems    NaN    NaN       NaN    NaN   suppress_cors_DMN
# 51  thought_problems  0.001 -0.020  0.056690  0.813                 NaN
# 52  thought_problems    NaN    NaN       NaN    NaN           Intercept
# 53  thought_problems    NaN    NaN       NaN    NaN  suppress_cors_FPCN
# 54  thought_problems  0.007 -0.015  0.306200  0.583                 NaN
# 55  thought_problems    NaN    NaN       NaN    NaN           Intercept
# 56  thought_problems    NaN    NaN       NaN    NaN   suppress_cors_SMN
# 57  thought_problems  0.000 -0.022  0.001453  0.970                 NaN
# 58  thought_problems    NaN    NaN       NaN    NaN           Intercept
# 59  thought_problems    NaN    NaN       NaN    NaN    suppress_cors_VN
#
#        coef  std err      t  P>|t|                                formula
# 0       NaN      NaN    NaN    NaN           thought_problems ~ main_cors
# 1    0.1077    0.157  0.687  0.495           thought_problems ~ main_cors
# 2   -2.1964    4.396 -0.500  0.620           thought_problems ~ main_cors
# 3       NaN      NaN    NaN    NaN        thought_problems ~ replace_cors
# 4    0.0965    0.161  0.600  0.551        thought_problems ~ replace_cors
# 5   -1.8690    4.848 -0.386  0.702        thought_problems ~ replace_cors
# 6       NaN      NaN    NaN    NaN       thought_problems ~ suppress_cors
# 7    0.0802    0.146  0.551  0.584       thought_problems ~ suppress_cors
# 8   -1.2682    4.177 -0.304  0.763       thought_problems ~ suppress_cors
# 9       NaN      NaN    NaN    NaN          thought_problems ~ clear_cors
# 10   0.1172    0.153  0.765  0.448          thought_problems ~ clear_cors
# 11  -1.3300    2.198 -0.605  0.548          thought_problems ~ clear_cors
# 12      NaN      NaN    NaN    NaN      thought_problems ~ clear_cors_DMN
# 13   0.0492    0.118  0.417  0.679      thought_problems ~ clear_cors_DMN
# 14   0.4498   39.579  0.011  0.991      thought_problems ~ clear_cors_DMN
# 15      NaN      NaN    NaN    NaN     thought_problems ~ clear_cors_FPCN
# 16   0.0490    0.124  0.397  0.693     thought_problems ~ clear_cors_FPCN
# 17   0.2018   18.131  0.011  0.991     thought_problems ~ clear_cors_FPCN
# 18      NaN      NaN    NaN    NaN      thought_problems ~ clear_cors_SMN
# 19   0.0356    0.120  0.297  0.768      thought_problems ~ clear_cors_SMN
# 20   8.1664   32.619  0.250  0.803      thought_problems ~ clear_cors_SMN
# 21      NaN      NaN    NaN    NaN       thought_problems ~ clear_cors_VN
# 22   0.0539    0.128  0.422  0.675       thought_problems ~ clear_cors_VN
# 23  -0.9125   15.698 -0.058  0.954       thought_problems ~ clear_cors_VN
# 24      NaN      NaN    NaN    NaN       thought_problems ~ main_cors_DMN
# 25   0.0748    0.127  0.590  0.558       thought_problems ~ main_cors_DMN
# 26 -83.5349  234.626 -0.356  0.723       thought_problems ~ main_cors_DMN
# 27      NaN      NaN    NaN    NaN      thought_problems ~ main_cors_FPCN
# 28   0.0416    0.119  0.349  0.728      thought_problems ~ main_cors_FPCN
# 29   6.5527   43.753  0.150  0.882      thought_problems ~ main_cors_FPCN
# 30      NaN      NaN    NaN    NaN       thought_problems ~ main_cors_SMN
# 31   0.0532    0.116  0.458  0.649       thought_problems ~ main_cors_SMN
# 32  -8.4043  117.550 -0.071  0.943       thought_problems ~ main_cors_SMN
# 33      NaN      NaN    NaN    NaN        thought_problems ~ main_cors_VN
# 34   0.0587    0.126  0.464  0.645        thought_problems ~ main_cors_VN
# 35  -2.4798   19.278 -0.129  0.898        thought_problems ~ main_cors_VN
# 36      NaN      NaN    NaN    NaN    thought_problems ~ replace_cors_DMN
# 37   0.0426    0.129  0.331  0.742    thought_problems ~ replace_cors_DMN
# 38  23.7019  242.800  0.098  0.923    thought_problems ~ replace_cors_DMN
# 39      NaN      NaN    NaN    NaN   thought_problems ~ replace_cors_FPCN
# 40   0.0440    0.121  0.363  0.718   thought_problems ~ replace_cors_FPCN
# 41   5.0155   52.431  0.096  0.924   thought_problems ~ replace_cors_FPCN
# 42      NaN      NaN    NaN    NaN    thought_problems ~ replace_cors_SMN
# 43   0.0425    0.122  0.349  0.729    thought_problems ~ replace_cors_SMN
# 44  17.4080  146.391  0.119  0.906    thought_problems ~ replace_cors_SMN
# 45      NaN      NaN    NaN    NaN     thought_problems ~ replace_cors_VN
# 46   0.0557    0.123  0.452  0.653     thought_problems ~ replace_cors_VN
# 47  -1.6966   17.972 -0.094  0.925     thought_problems ~ replace_cors_VN
# 48      NaN      NaN    NaN    NaN   thought_problems ~ suppress_cors_DMN
# 49   0.0115    0.124  0.093  0.927   thought_problems ~ suppress_cors_DMN
# 50  84.4606  143.360  0.589  0.559   thought_problems ~ suppress_cors_DMN
# 51      NaN      NaN    NaN    NaN  thought_problems ~ suppress_cors_FPCN
# 52   0.0648    0.123  0.527  0.601  thought_problems ~ suppress_cors_FPCN
# 53 -10.1941   42.814 -0.238  0.813  thought_problems ~ suppress_cors_FPCN
# 54      NaN      NaN    NaN    NaN   thought_problems ~ suppress_cors_SMN
# 55   0.0209    0.118  0.178  0.859   thought_problems ~ suppress_cors_SMN
# 56  58.2716  105.314  0.553  0.583   thought_problems ~ suppress_cors_SMN
# 57      NaN      NaN    NaN    NaN    thought_problems ~ suppress_cors_VN
# 58   0.0520    0.121  0.429  0.670    thought_problems ~ suppress_cors_VN
# 59  -0.5902   15.483 -0.038  0.970    thought_problems ~ suppress_cors_VN
